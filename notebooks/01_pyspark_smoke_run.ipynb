# %% [markdown]
# # PySpark MVP Smoke Run
#
# This notebook is the first runnable path for the Portuguese Simile Candidate Explorer MVP. It verifies that the Dockerized Jupyter PySpark runtime starts Spark, imports this repository, and loads a tiny Portuguese text sample through Spark.

# %%
from pathlib import Path
import sys

def find_repo_root(start: Path) -> Path:
    for path in [start, *start.parents]:
        if (path / "src" / "tal_qual").exists():
            return path
    raise RuntimeError("Could not find repository root containing src/tal_qual")

REPO_ROOT = find_repo_root(Path.cwd().resolve())
SRC_DIR = REPO_ROOT / "src"

if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

REPO_ROOT

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("tal-qual-smoke-run")
    .getOrCreate()
)

spark.version

# %%
from tal_qual import SAMPLE_TEXT_PATH, load_sample_text

SAMPLE_TEXT_PATH

# %%
sample_df = load_sample_text(spark, REPO_ROOT)

sample_df.count(), sample_df.columns

# %%
sample_df.show(truncate=False)
